# %%
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
myModel = load_model('saved_models/gray_scale/model_2020-03-18.h5')

# %%
img = imread('MUSE/testA/Stack0090.jpg', as_gray = True)
pred = myModel.predict(img.reshape(1,512,512,1))

# %%
plt.imshow(pred.reshape(512,512,3))
